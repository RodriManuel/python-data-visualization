# %% [markdown]
# # Visualizando trayectorias aleatorias
# En este notebook vamos a explorar el concepto de **Random Walk** (camino aleatorio), una simulación matemática que describe un camino formado por una sucesión de pasos aleatorios.
#
# ## Objetivos
# - Comprender qué es un Random Walk.
# - Implementar una simulación bidimensional.
# - Visualizar trayectorias utilizando Matplotlib.
# - Explorar cómo cambian los resultados entre simulaciones.
# - Generar gráficos exportables para el repositorio.

# %%
# Configuración del entorno
import sys
from pathlib import Path

# Añade la carpeta padre (raíz del proyecto) al path de Python
sys.path.append(str(Path.cwd().parent))

import matplotlib.pyplot as plt

from src.random_walk import RandomWalk

# %% [markdown]
# ### Construcción de la clase RandomWalk
# La clase *RandomWalk* encapsula la lógica para generar trayectorias aleatorias.
#
# La importamos desde el archivo *random_walk.py* en la carpeta *src/* para separar la lógica del análisis.

# %% [markdown]
# ### Primera Visualización

# %%
# Generamos un random walk.
rw_1 = RandomWalk()
rw_1.trazar_camino()

# Graficamos las posiciones del random walk.
plt.style.use('classic')

fig, ax = plt.subplots()

ax.scatter(rw_1.get_x_values(), rw_1.get_y_values(), s=15)
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# ### Modificabdo el estilo
# Es útil modificar el estilo de este tipo de gráficos para enfatizar las características de cada camino y quitar los elementos que pueden distraernos de lo importante.
#
# Algunas características a enfatizar son:
# - En dónde comienza el camino
# - En dónde termina el camino
# - Hacia dónde se dirigen los pasos
#
# Mientras que vamos a quitar otras como:
# - Las etiquetas y números, útiles para otro tipo de gráficos

# %% [markdown]
# #### Usamos color map

# %%
# Generamos un random walk.
rw_2 = RandomWalk()
rw_2.trazar_camino()

# Graficamos las posiciones del random walk.
plt.style.use('classic')

fig, ax = plt.subplots()

point_numbers = range(rw_2.get_number_points())

ax.scatter(rw_2.get_x_values(), rw_2.get_y_values(), c=point_numbers, cmap=plt.cm.Blues, edgecolors='none', s=15)
ax.set_aspect('equal')

plt.show()

# %% [markdown]
# #### Enfatizamos el inicio y el final
# Agregamos al código las siguientes líneas:
#
# *ax.scatter(0, 0, c='green', edgecolors='none', s=150)*
#
# *ax.scatter(rw_3.get_x_values()[-1], rw_3.get_y_values()[-1], c='red', edgecolors='none', s=100)*

# %%
# Generamos un random walk.
rw_3 = RandomWalk()
rw_3.trazar_camino()

# Graficamos las posiciones del random walk.
plt.style.use('classic')

fig, ax = plt.subplots()

point_numbers = range(rw_3.get_number_points())

ax.scatter(rw_3.get_x_values(), rw_3.get_y_values(), c=point_numbers, cmap=plt.cm.Blues, edgecolors='none', s=15)
ax.set_aspect('equal')

# Enfatizamos el primer y último punto
ax.scatter(0, 0, c='green', edgecolors='none', s=150)
ax.scatter(rw_3.get_x_values()[-1], rw_3.get_y_values()[-1], c='red', edgecolors='none', s=100)

plt.show()

# %% [markdown]
# #### Eliminar ejes
# Para este tipo de gráficos los ejes son inútiles y solamente ocupan espacio. Los eliminamos así:

# %%
# Generamos un random walk.
rw_4 = RandomWalk()
rw_4.trazar_camino()

# Graficamos las posiciones del random walk.
plt.style.use('classic')

fig, ax = plt.subplots()

point_numbers = range(rw_4.get_number_points())

ax.scatter(rw_4.get_x_values(), rw_4.get_y_values(), c=point_numbers, cmap=plt.cm.Blues, edgecolors='none', s=15)
ax.set_aspect('equal')

# Enfatizamos el primer y último punto
ax.scatter(0, 0, c='green', edgecolors='none', s=150)
ax.scatter(rw_4.get_x_values()[-1], rw_4.get_y_values()[-1], c='red', edgecolors='none', s=100)

# Quitamos los ejes
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# ### Incrementando la cantidad de puntos
# Hasta ahora venimos generando Random Walks usando el valor por defecto de 1000 puntos.
#
# Vamos a ver diferentes valores:

# %% [markdown]
# #### 5000 puntos

# %%
# Generamos un random walk.
rw_5 = RandomWalk(5000)
rw_5.trazar_camino()

# Graficamos las posiciones del random walk.
plt.style.use('classic')

fig, ax = plt.subplots()

point_numbers = range(rw_5.get_number_points())

ax.scatter(rw_5.get_x_values(), rw_5.get_y_values(), c=point_numbers, cmap=plt.cm.Blues, edgecolors='none', s=15)
ax.set_aspect('equal')

# Enfatizamos el primer y último punto
ax.scatter(0, 0, c='green', edgecolors='none', s=150)
ax.scatter(rw_5.get_x_values()[-1], rw_5.get_y_values()[-1], c='red', edgecolors='none', s=100)

# Quitamos los ejes
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# #### 25.000 puntos

# %%
# Generamos un random walk.
rw_6 = RandomWalk(25_000)
rw_6.trazar_camino()

# Graficamos las posiciones del random walk.
plt.style.use('classic')

fig, ax = plt.subplots(figsize=(15, 9))

point_numbers = range(rw_6.get_number_points())

ax.scatter(rw_6.get_x_values(), rw_6.get_y_values(), c=point_numbers, cmap=plt.cm.Blues, edgecolors='none', s=15)
ax.set_aspect('equal')

# Enfatizamos el primer y último punto
ax.scatter(0, 0, c='green', edgecolors='none', s=150)
ax.scatter(rw_6.get_x_values()[-1], rw_6.get_y_values()[-1], c='red', edgecolors='none', s=100)

# Quitamos los ejes
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.show()

# %% [markdown]
# #### 50.000 puntos

# %%
# Generamos un random walk.
rw_7 = RandomWalk(50_000)
rw_7.trazar_camino()

# Graficamos las posiciones del random walk.
plt.style.use('classic')

fig, ax = plt.subplots(figsize=(15, 9))

point_numbers = range(rw_7.get_number_points())

ax.scatter(rw_7.get_x_values(), rw_7.get_y_values(), c=point_numbers, cmap=plt.cm.Blues, edgecolors='none', s=15)
ax.set_aspect('equal')

# Enfatizamos el primer y último punto
ax.scatter(0, 0, c='green', edgecolors='none', s=150)
ax.scatter(rw_7.get_x_values()[-1], rw_7.get_y_values()[-1], c='red', edgecolors='none', s=100)

# Quitamos los ejes
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

plt.show()
